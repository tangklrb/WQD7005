# %%
import pandas as pd
from apyori import apriori

# %%
df = pd.read_csv('lab2.csv')

# %%
df.head()
# Out:
#    ACCOUNT SERVICE  VISIT
# 0   500026   CKING      1
# 1   500026     SVG      2
# 2   500026     ATM      3
# 3   500026     ATM      4
# 4   500075   CKING      1

# %%
# Group all Services by the same Account as a list

transactions = dict()
for index, row in df.iterrows():
    if row['ACCOUNT'] not in transactions.keys():
        transactions[row['ACCOUNT']] = list()
    
    transactions[row['ACCOUNT']].append(row['SERVICE'])

# Convert into pandas dataframe
transactions = pd.DataFrame(list(transactions.items()), columns = ['Account','Services'])

# All last item of a transaction in the dataset are repeated
# Remove duplicated services used by the same account (Not required)
# transactions['Services'] = transactions['Services'].apply(lambda x: set(x))

# one hot encoding
# services = pd.get_dummies(df['SERVICE'], drop_first=False)
# df.drop('SERVICE', axis = 1, inplace = True)
# df.drop('VISIT', axis = 1, inplace = True)
# df = pd.concat([df, services], axis = 1)

# %%
transactions.head(10)
# Out:
#    Account                                       Services
# 0   500026                         [CKING, SVG, ATM, ATM]
# 1   500075          [CKING, MMDA, SVG, ATM, TRUST, TRUST]
# 2   500129                    [CKING, SVG, IRA, ATM, ATM]
# 3   500256                     [CKING, SVG, CKCRD, CKCRD]
# 4   500341                     [CKING, SVG, CKCRD, CKCRD]
# 5   500350                                [CKING, CD, CD]
# 6   500458                                [SVG, ATM, ATM]
# 7   500595                 [CKING, SVG, CD, TRUST, TRUST]
# 8   500743  [CKING, SVG, CCRD, HMEQLC, MTG, CKCRD, CKCRD]
# 9   500744                                [CKING, CD, CD]

# %%
# Apply apriori algorithm to the services column
association_rules = apriori(transactions['Services'], min_support=0.05)  
association_results = list(association_rules)

# %%
# view results in dataframe
pd.DataFrame(association_results)
# Out:
#                         items   support  \
# 0                       (ATM)  0.384558
# 1                      (AUTO)  0.092854
# 2                      (CCRD)  0.154799
# 3                        (CD)  0.245276
# 4                     (CKCRD)  0.113002
# 5                     (CKING)  0.857840
# 6                    (HMEQLC)  0.164685
# 7                       (IRA)  0.108372
# 8                      (MMDA)  0.174446
# 9                       (MTG)  0.074334
# 10                      (SVG)  0.618696
# 11                  (CD, ATM)  0.071581
# 12               (CKING, ATM)  0.361907
# 13              (HMEQLC, ATM)  0.085346
# 14                (MMDA, ATM)  0.053310
# 15                 (SVG, ATM)  0.256914
# 16              (AUTO, CKING)  0.085221
# 17                (AUTO, SVG)  0.061444
# 18              (CCRD, CKCRD)  0.055813
# 19              (CCRD, CKING)  0.148542
# 20                (CCRD, SVG)  0.102240
# 21                (CKING, CD)  0.209861
# 22                 (MMDA, CD)  0.050181
# 23                  (SVG, CD)  0.157177
# 24             (CKING, CKCRD)  0.113002
# 25               (SVG, CKCRD)  0.079715
# 26            (CKING, HMEQLC)  0.164685
# 27               (CKING, IRA)  0.088224
# 28              (CKING, MMDA)  0.155800
# 29               (CKING, MTG)  0.072707
# 30               (CKING, SVG)  0.541734
# 31              (SVG, HMEQLC)  0.111500
# 32                 (IRA, SVG)  0.063947
# 33                (SVG, MMDA)  0.077337
# 34           (CKING, CD, ATM)  0.070079
# 35             (SVG, CD, ATM)  0.053811
# 36       (CKING, HMEQLC, ATM)  0.085346
# 37         (CKING, MMDA, ATM)  0.051683
# 38          (CKING, SVG, ATM)  0.248530
# 39         (SVG, HMEQLC, ATM)  0.060944
# 40         (AUTO, SVG, CKING)  0.059692
# 41       (CCRD, CKCRD, CKING)  0.055813
# 42         (CCRD, SVG, CKING)  0.099862
# 43           (CKING, SVG, CD)  0.142535
# 44        (CKING, SVG, CKCRD)  0.079715
# 45       (CKING, SVG, HMEQLC)  0.111500
# 46          (CKING, SVG, IRA)  0.059567
# 47         (CKING, SVG, MMDA)  0.073583
# 48      (CKING, SVG, CD, ATM)  0.052559
# 49  (CKING, SVG, HMEQLC, ATM)  0.060944
#
#                                    ordered_statistics
# 0              [((), (ATM), 0.3845576273307471, 1.0)]
# 1            [((), (AUTO), 0.09285446126892755, 1.0)]
# 2              [((), (CCRD), 0.154799149042673, 1.0)]
# 3              [((), (CD), 0.24527593542735576, 1.0)]
# 4           [((), (CKCRD), 0.11300212739331748, 1.0)]
# 5            [((), (CKING), 0.8578400700788387, 1.0)]
# 6            [((), (HMEQLC), 0.164685270929796, 1.0)]
# 7             [((), (IRA), 0.10837191840820924, 1.0)]
# 8            [((), (MMDA), 0.17444625203353772, 1.0)]
# 9             [((), (MTG), 0.07433362532849455, 1.0)]
# 10             [((), (SVG), 0.6186960330371668, 1.0)]
# 11  [((), (ATM, CD), 0.07158052809410587, 1.0), ((...
# 12  [((), (CKING, ATM), 0.36190714553873105, 1.0),...
# 13  [((), (HMEQLC, ATM), 0.0853460142660493, 1.0),...
# 14  [((), (MMDA, ATM), 0.05330997372043549, 1.0), ...
# 15  [((), (SVG, ATM), 0.25691402828181703, 1.0), (...
# 16  [((), (AUTO, CKING), 0.085220873482668, 1.0), ...
# 17  [((), (AUTO, SVG), 0.06144412464022025, 1.0), ...
# 18  [((), (CCRD, CKCRD), 0.05581278938806157, 1.0)...
# 19  [((), (CCRD, CKING), 0.1485421098736078, 1.0),...
# 20  [((), (CCRD, SVG), 0.10224002002252534, 1.0), ...
# 21  [((), (CKING, CD), 0.20986109373044676, 1.0), ...
# 22  [((), (MMDA, CD), 0.05018145413590289, 1.0), (...
# 23  [((), (SVG, CD), 0.15717682392691779, 1.0), ((...
# 24  [((), (CKING, CKCRD), 0.11300212739331748, 1.0...
# 25  [((), (SVG, CKCRD), 0.07971467901389062, 1.0),...
# 26  [((), (CKING, HMEQLC), 0.164685270929796, 1.0)...
# 27  [((), (CKING, IRA), 0.08822425228381929, 1.0),...
# 28  [((), (CKING, MMDA), 0.15580027530972343, 1.0)...
# 29  [((), (CKING, MTG), 0.07270679514453761, 1.0),...
# 30  [((), (CKING, SVG), 0.5417344512576648, 1.0), ...
# 31  [((), (SVG, HMEQLC), 0.11150043799274184, 1.0)...
# 32  [((), (IRA, SVG), 0.06394694030784633, 1.0), (...
# 33  [((), (SVG, MMDA), 0.07733700412964585, 1.0), ...
# 34  [((), (CKING, ATM, CD), 0.07007883869353022, 1...
# 35  [((), (SVG, ATM, CD), 0.05381053685396071, 1.0...
# 36  [((), (CKING, HMEQLC, ATM), 0.0853460142660493...
# 37  [((), (CKING, MMDA, ATM), 0.051683143536478536...
# 38  [((), (CKING, SVG, ATM), 0.24852959579526968, ...
# 39  [((), (SVG, HMEQLC, ATM), 0.06094356150669503,...
# 40  [((), (AUTO, SVG, CKING), 0.05969215367288199,...
# 41  [((), (CCRD, CKCRD, CKING), 0.0558127893880615...
# 42  [((), (CCRD, SVG, CKING), 0.09986234513828056,...
# 43  [((), (CKING, SVG, CD), 0.1425353522713052, 1....
# 44  [((), (CKING, SVG, CKCRD), 0.07971467901389062...
# 45  [((), (CKING, SVG, HMEQLC), 0.1115004379927418...
# 46  [((), (CKING, SVG, IRA), 0.05956701288950069, ...
# 47  [((), (CKING, SVG, MMDA), 0.07358278062820674,...
# 48  [((), (CKING, SVG, CD, ATM), 0.052559129020147...
# 49  [((), (CKING, SVG, HMEQLC, ATM), 0.06094356150...

# %%
# For better view, unpack ordered_statistics
# codes below is taken from https://stackoverflow.com/questions/52688220/python-apyori-sorting-by-lift

results = pd.DataFrame(columns=('Items','Antecedent','Consequent','Support','Confidence','Lift'))

Support =[]
Confidence = []
Lift = []
Items = []
Antecedent = []
Consequent=[]

for RelationRecord in association_results:
    for ordered_stat in RelationRecord.ordered_statistics:
        Support.append(RelationRecord.support)
        Items.append(RelationRecord.items)
        Antecedent.append(ordered_stat.items_base)
        Consequent.append(ordered_stat.items_add)
        Confidence.append(ordered_stat.confidence)
        Lift.append(ordered_stat.lift)

results['Items'] = list(map(set, Items))                                   
results['Antecedent'] = list(map(set, Antecedent))
results['Consequent'] = list(map(set, Consequent))
results['Support'] = Support
results['Confidence'] = Confidence
results['Lift']= Lift

results.sort_index(ascending = False, inplace = True)
results.head(50)
# Out:
#                          Items            Antecedent  \
# 207  {CKING, SVG, HMEQLC, ATM}  {CKING, SVG, HMEQLC}
# 206  {CKING, SVG, HMEQLC, ATM}    {SVG, HMEQLC, ATM}
# 205  {CKING, SVG, HMEQLC, ATM}     {CKING, SVG, ATM}
# 204  {CKING, SVG, HMEQLC, ATM}  {CKING, HMEQLC, ATM}
# 203  {CKING, SVG, HMEQLC, ATM}         {SVG, HMEQLC}
# 202  {CKING, SVG, HMEQLC, ATM}          {CKING, SVG}
# 201  {CKING, SVG, HMEQLC, ATM}       {CKING, HMEQLC}
# 200  {CKING, SVG, HMEQLC, ATM}            {SVG, ATM}
# 199  {CKING, SVG, HMEQLC, ATM}         {HMEQLC, ATM}
# 198  {CKING, SVG, HMEQLC, ATM}          {CKING, ATM}
# 197  {CKING, SVG, HMEQLC, ATM}                 {SVG}
# 196  {CKING, SVG, HMEQLC, ATM}              {HMEQLC}
# 195  {CKING, SVG, HMEQLC, ATM}               {CKING}
# 194  {CKING, SVG, HMEQLC, ATM}                 {ATM}
# 193  {CKING, SVG, HMEQLC, ATM}                    {}
# 192      {CKING, SVG, CD, ATM}      {CKING, SVG, CD}
# 191      {CKING, SVG, CD, ATM}     {CKING, SVG, ATM}
# 190      {CKING, SVG, CD, ATM}        {SVG, CD, ATM}
# 189      {CKING, SVG, CD, ATM}      {CKING, CD, ATM}
# 188      {CKING, SVG, CD, ATM}          {CKING, SVG}
# 187      {CKING, SVG, CD, ATM}             {SVG, CD}
# 186      {CKING, SVG, CD, ATM}           {CKING, CD}
# 185      {CKING, SVG, CD, ATM}            {SVG, ATM}
# 184      {CKING, SVG, CD, ATM}          {CKING, ATM}
# 183      {CKING, SVG, CD, ATM}             {CD, ATM}
# 182      {CKING, SVG, CD, ATM}                 {SVG}
# 181      {CKING, SVG, CD, ATM}               {CKING}
# 180      {CKING, SVG, CD, ATM}                  {CD}
# 179      {CKING, SVG, CD, ATM}                 {ATM}
# 178      {CKING, SVG, CD, ATM}                    {}
# 177         {CKING, SVG, MMDA}           {SVG, MMDA}
# 176         {CKING, SVG, MMDA}          {CKING, SVG}
# 175         {CKING, SVG, MMDA}         {CKING, MMDA}
# 174         {CKING, SVG, MMDA}                 {SVG}
# 173         {CKING, SVG, MMDA}                {MMDA}
# 172         {CKING, SVG, MMDA}               {CKING}
# 171         {CKING, SVG, MMDA}                    {}
# 170          {CKING, SVG, IRA}            {IRA, SVG}
# 169          {CKING, SVG, IRA}          {CKING, SVG}
# 168          {CKING, SVG, IRA}          {CKING, IRA}
# 167          {CKING, SVG, IRA}                 {SVG}
# 166          {CKING, SVG, IRA}                 {IRA}
# 165          {CKING, SVG, IRA}               {CKING}
# 164          {CKING, SVG, IRA}                    {}
# 163       {CKING, SVG, HMEQLC}         {SVG, HMEQLC}
# 162       {CKING, SVG, HMEQLC}          {CKING, SVG}
# 161       {CKING, SVG, HMEQLC}       {CKING, HMEQLC}
# 160       {CKING, SVG, HMEQLC}                 {SVG}
# 159       {CKING, SVG, HMEQLC}              {HMEQLC}
# 158       {CKING, SVG, HMEQLC}               {CKING}
#
#                     Consequent   Support  Confidence      Lift
# 207                      {ATM}  0.060944    0.546577  1.421313
# 206                    {CKING}  0.060944    1.000000  1.165718
# 205                   {HMEQLC}  0.060944    0.245217  1.489001
# 204                      {SVG}  0.060944    0.714076  1.154163
# 203               {CKING, ATM}  0.060944    0.546577  1.510268
# 202              {HMEQLC, ATM}  0.060944    0.112497  1.318130
# 201                 {SVG, ATM}  0.060944    0.370061  1.440407
# 200            {CKING, HMEQLC}  0.060944    0.237214  1.440407
# 199               {CKING, SVG}  0.060944    0.714076  1.318130
# 198              {SVG, HMEQLC}  0.060944    0.168396  1.510268
# 197       {CKING, HMEQLC, ATM}  0.060944    0.098503  1.154163
# 196          {CKING, SVG, ATM}  0.060944    0.370061  1.489001
# 195         {SVG, HMEQLC, ATM}  0.060944    0.071043  1.165718
# 194       {CKING, SVG, HMEQLC}  0.060944    0.158477  1.421313
# 193  {CKING, SVG, HMEQLC, ATM}  0.060944    0.060944  1.000000
# 192                      {ATM}  0.052559    0.368745  0.958880
# 191                       {CD}  0.052559    0.211480  0.862214
# 190                    {CKING}  0.052559    0.976744  1.138609
# 189                      {SVG}  0.052559    0.750000  1.212227
# 188                  {ATM, CD}  0.052559    0.097020  1.355398
# 187               {CKING, ATM}  0.052559    0.334395  0.923980
# 186                 {SVG, ATM}  0.052559    0.250447  0.974829
# 185                {CKING, CD}  0.052559    0.204579  0.974829
# 184                  {SVG, CD}  0.052559    0.145228  0.923980
# 183               {CKING, SVG}  0.052559    0.734266  1.355398
# 182           {CKING, ATM, CD}  0.052559    0.084951  1.212227
# 181             {SVG, ATM, CD}  0.052559    0.061269  1.138609
# 180          {CKING, SVG, ATM}  0.052559    0.214286  0.862214
# 179           {CKING, SVG, CD}  0.052559    0.136674  0.958880
# 178      {CKING, SVG, CD, ATM}  0.052559    0.052559  1.000000
# 177                    {CKING}  0.073583    0.951456  1.109130
# 176                     {MMDA}  0.073583    0.135828  0.778625
# 175                      {SVG}  0.073583    0.472289  0.763362
# 174              {CKING, MMDA}  0.073583    0.118932  0.763362
# 173               {CKING, SVG}  0.073583    0.421808  0.778625
# 172                {SVG, MMDA}  0.073583    0.085777  1.109130
# 171         {CKING, SVG, MMDA}  0.073583    0.073583  1.000000
# 170                    {CKING}  0.059567    0.931507  1.085875
# 169                      {IRA}  0.059567    0.109956  1.014618
# 168                      {SVG}  0.059567    0.675177  1.091291
# 167               {CKING, IRA}  0.059567    0.096278  1.091291
# 166               {CKING, SVG}  0.059567    0.549654  1.014618
# 165                 {IRA, SVG}  0.059567    0.069438  1.085875
# 164          {CKING, SVG, IRA}  0.059567    0.059567  1.000000
# 163                    {CKING}  0.111500    1.000000  1.165718
# 162                   {HMEQLC}  0.111500    0.205821  1.249785
# 161                      {SVG}  0.111500    0.677052  1.094320
# 160            {CKING, HMEQLC}  0.111500    0.180218  1.094320
# 159               {CKING, SVG}  0.111500    0.677052  1.249785
# 158              {SVG, HMEQLC}  0.111500    0.129978  1.165718

# %%
# Sort by Lift
results.sort_values(by ='Lift', ascending = False, inplace = True)
results.head(50)
# Out:
#                          Items            Antecedent            Consequent  \
# 134       {CCRD, CKCRD, CKING}         {CCRD, CKING}               {CKCRD}
# 131       {CCRD, CKCRD, CKING}               {CKCRD}         {CCRD, CKING}
# 33               {CCRD, CKCRD}                {CCRD}               {CKCRD}
# 130       {CCRD, CKCRD, CKING}                {CCRD}        {CKING, CKCRD}
# 34               {CCRD, CKCRD}               {CKCRD}                {CCRD}
# 135       {CCRD, CKCRD, CKING}        {CKING, CKCRD}                {CCRD}
# 203  {CKING, SVG, HMEQLC, ATM}         {SVG, HMEQLC}          {CKING, ATM}
# 198  {CKING, SVG, HMEQLC, ATM}          {CKING, ATM}         {SVG, HMEQLC}
# 196  {CKING, SVG, HMEQLC, ATM}              {HMEQLC}     {CKING, SVG, ATM}
# 205  {CKING, SVG, HMEQLC, ATM}     {CKING, SVG, ATM}              {HMEQLC}
# 201  {CKING, SVG, HMEQLC, ATM}       {CKING, HMEQLC}            {SVG, ATM}
# 117         {SVG, HMEQLC, ATM}              {HMEQLC}            {SVG, ATM}
# 200  {CKING, SVG, HMEQLC, ATM}            {SVG, ATM}       {CKING, HMEQLC}
# 120         {SVG, HMEQLC, ATM}            {SVG, ATM}              {HMEQLC}
# 97        {CKING, HMEQLC, ATM}              {HMEQLC}          {CKING, ATM}
# 98        {CKING, HMEQLC, ATM}          {CKING, ATM}              {HMEQLC}
# 116         {SVG, HMEQLC, ATM}                 {ATM}         {SVG, HMEQLC}
# 121         {SVG, HMEQLC, ATM}         {SVG, HMEQLC}                 {ATM}
# 207  {CKING, SVG, HMEQLC, ATM}  {CKING, SVG, HMEQLC}                 {ATM}
# 194  {CKING, SVG, HMEQLC, ATM}                 {ATM}  {CKING, SVG, HMEQLC}
# 188      {CKING, SVG, CD, ATM}          {CKING, SVG}             {ATM, CD}
# 183      {CKING, SVG, CD, ATM}             {CD, ATM}          {CKING, SVG}
# 19               {HMEQLC, ATM}              {HMEQLC}                 {ATM}
# 95        {CKING, HMEQLC, ATM}                 {ATM}       {CKING, HMEQLC}
# 18               {HMEQLC, ATM}                 {ATM}              {HMEQLC}
# 100       {CKING, HMEQLC, ATM}       {CKING, HMEQLC}                 {ATM}
# 199  {CKING, SVG, HMEQLC, ATM}         {HMEQLC, ATM}          {CKING, SVG}
# 202  {CKING, SVG, HMEQLC, ATM}          {CKING, SVG}         {HMEQLC, ATM}
# 156        {CKING, SVG, CKCRD}          {CKING, SVG}               {CKCRD}
# 151        {CKING, SVG, CKCRD}               {CKCRD}          {CKING, SVG}
# 159       {CKING, SVG, HMEQLC}              {HMEQLC}          {CKING, SVG}
# 162       {CKING, SVG, HMEQLC}          {CKING, SVG}              {HMEQLC}
# 91              {SVG, CD, ATM}             {CD, ATM}                 {SVG}
# 90              {SVG, CD, ATM}                 {SVG}             {ATM, CD}
# 182      {CKING, SVG, CD, ATM}                 {SVG}      {CKING, ATM, CD}
# 189      {CKING, SVG, CD, ATM}      {CKING, CD, ATM}                 {SVG}
# 109          {CKING, SVG, ATM}                 {ATM}          {CKING, SVG}
# 114          {CKING, SVG, ATM}          {CKING, SVG}                 {ATM}
# 142         {CCRD, SVG, CKING}          {CKING, SVG}                {CCRD}
# 137         {CCRD, SVG, CKING}                {CCRD}          {CKING, SVG}
# 128         {AUTO, SVG, CKING}          {CKING, SVG}                {AUTO}
# 123         {AUTO, SVG, CKING}                {AUTO}          {CKING, SVG}
# 46                  {MMDA, CD}                {MMDA}                  {CD}
# 45                  {MMDA, CD}                  {CD}                {MMDA}
# 155        {CKING, SVG, CKCRD}          {SVG, CKCRD}               {CKING}
# 133       {CCRD, CKCRD, CKING}         {CCRD, CKCRD}               {CKING}
# 158       {CKING, SVG, HMEQLC}               {CKING}         {SVG, HMEQLC}
# 96        {CKING, HMEQLC, ATM}               {CKING}         {HMEQLC, ATM}
# 58             {CKING, HMEQLC}              {HMEQLC}               {CKING}
# 163       {CKING, SVG, HMEQLC}         {SVG, HMEQLC}               {CKING}
#
#       Support  Confidence      Lift
# 134  0.055813    0.375737  3.325045
# 131  0.055813    0.493909  3.325045
# 33   0.055813    0.360550  3.190645
# 130  0.055813    0.360550  3.190645
# 34   0.055813    0.493909  3.190645
# 135  0.055813    0.493909  3.190645
# 203  0.060944    0.546577  1.510268
# 198  0.060944    0.168396  1.510268
# 196  0.060944    0.370061  1.489001
# 205  0.060944    0.245217  1.489001
# 201  0.060944    0.370061  1.440407
# 117  0.060944    0.370061  1.440407
# 200  0.060944    0.237214  1.440407
# 120  0.060944    0.237214  1.440407
# 97   0.085346    0.518237  1.431961
# 98   0.085346    0.235823  1.431961
# 116  0.060944    0.158477  1.421313
# 121  0.060944    0.546577  1.421313
# 207  0.060944    0.546577  1.421313
# 194  0.060944    0.158477  1.421313
# 188  0.052559    0.097020  1.355398
# 183  0.052559    0.734266  1.355398
# 19   0.085346    0.518237  1.347619
# 95   0.085346    0.221933  1.347619
# 18   0.085346    0.221933  1.347619
# 100  0.085346    0.518237  1.347619
# 199  0.060944    0.714076  1.318130
# 202  0.060944    0.112497  1.318130
# 156  0.079715    0.147147  1.302163
# 151  0.079715    0.705426  1.302163
# 159  0.111500    0.677052  1.249785
# 162  0.111500    0.205821  1.249785
# 91   0.053811    0.751748  1.215053
# 90   0.053811    0.086974  1.215053
# 182  0.052559    0.084951  1.212227
# 189  0.052559    0.750000  1.212227
# 109  0.248530    0.646274  1.192972
# 114  0.248530    0.458766  1.192972
# 142  0.099862    0.184338  1.190822
# 137  0.099862    0.645109  1.190822
# 128  0.059692    0.110187  1.186665
# 123  0.059692    0.642857  1.186665
# 46   0.050181    0.287661  1.172807
# 45   0.050181    0.204592  1.172807
# 155  0.079715    1.000000  1.165718
# 133  0.055813    1.000000  1.165718
# 158  0.111500    0.129978  1.165718
# 96   0.085346    0.099489  1.165718
# 58   0.164685    1.000000  1.165718
# 163  0.111500    1.000000  1.165718
