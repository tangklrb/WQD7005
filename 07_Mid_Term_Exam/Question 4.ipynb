# %%
import numpy as np 
import pandas as pd
import datetime
from geopy.distance import distance

# %%
# load data from csv

data_directory = 'data/'

q3_township_csv = data_directory + 'q3_townships.csv'
q3_transaction_csv = data_directory + 'q3_transactions.csv'
q3_poi_csv = data_directory + 'q3_pois.csv'

township_csv = data_directory + 'q4_townships.csv'
transaction_csv = data_directory + 'q4_transactions.csv'
poi_csv = data_directory + 'q4_pois.csv'

townships = pd.read_csv(q3_township_csv, na_values=['None'], index_col=0)
transactions = pd.read_csv(q3_transaction_csv, na_values=['None'], index_col=0)
pois = pd.read_csv(q3_poi_csv, na_values=['None'], index_col=0)

# %%
townships
# Out:
#      project_id  latitude   longitude                          project_name  \
# 0         10113  3.200030  101.642998                           Kepong Baru
# 1         16814  3.087248  101.721283     Bandar Tun Razak (Kampung Konggo)
# 2         16319  3.181050  101.672996                        Sri Putramas I
# 3         17003  3.149142  101.624763            Taman Tun Dr Ismail (TTDI)
# 4         25133  3.192106  101.639056  Bandar Menjalara (Desa Seri Mahkota)
# ..          ...       ...         ...                                   ...
# 127       13600  3.060640  101.585999                                 USJ 2
# 128       13603  3.024680  101.584999                                USJ 22
# 129       13606  3.056050  101.571999                                 USJ 3
# 130       13632  3.080259  101.774374                           Venice Hill
# 131       28198  2.899456  101.661448                           PPA1M Larai
#
#             state                 area             street_name  median_psf  \
# 0    Kuala Lumpur               Kepong            JALAN HELANG         388
# 1    Kuala Lumpur     Bandar Tun Razak           JALAN JUJUR 3         294
# 2    Kuala Lumpur              Dutamas        JALAN PUTRAMAS 1         394
# 3    Kuala Lumpur  Taman Tun Dr Ismail  LENGKOK AMINUDDIN BAKI         814
# 4    Kuala Lumpur     Bandar Menjalara              JALAN 6/62         512
# ..            ...                  ...                     ...         ...
# 127      Selangor                  USJ          JALAN USJ 2/4E         432
# 128      Selangor                  USJ         JALAN USJ 22/2B         343
# 129      Selangor                  USJ          JALAN USJ 3/4B         619
# 130      Selangor      Batu 9th Cheras      PERSIARAN PUTERI 1          78
# 131     Putrajaya            Putrajaya               PRESINT 6         216
#
#      median_price
# 0          775000
# 1          396667
# 2          432667
# 3         1541667
# 4          635000
# ..            ...
# 127        675000
# 128        850000
# 129        740000
# 130        120000
# 131        260000
#
# [126 rows x 9 columns]

# %%
pois
# Out:
#                                                 name   category  latitude  \
# 0            Sekolah Menengah Kebangsaan Kepong Baru  education  3.197770
# 1                    Sekolah Kebangsaan Taman Kepong  education  3.198950
# 2                     Sekolah Kebangsaan Kepong Baru  education  3.205899
# 3                       Sekolah Kebangsaan Menjalara  education  3.193969
# 4     Sekolah Menengah Kebangsaan Taman Bukit Maluri  education  3.202450
# ...                                              ...        ...       ...
# 5358               Sekolah Kebangsaan Seksyen 27 (2)  education  3.016785
# 5359          Sekolah Menengah Kebangsaan Seksyen 27  education  3.021596
# 5361                Sekolah Kebangsaan Seksyen 27(1)  education  3.020541
# 5362          Sekolah Menengah Kebangsaan Alam Megah  education  3.012403
# 5365          Sekolah Jenis Kebangsaan (Tamil) Hicom  education  3.019865
#
#        longitude
# 0     101.647000
# 1     101.648000
# 2     101.645528
# 3     101.637578
# 4     101.634000
# ...          ...
# 5358  101.570449
# 5359  101.566105
# 5361  101.565389
# 5362  101.568793
# 5365  101.564861
#
# [1255 rows x 4 columns]

# %%
transactions
# Out:
#      project_id        date          property_type  area_sqft  non_landed  \
# 0         10113  1576454400          Terrace House       1970           0
# 1         10113  1576195200          Terrace House       1539           0
# 2         10113  1576108800          Terrace House       1539           0
# 3         10113  1575936000          Terrace House       3272           0
# 4         16814  1575936000          Cluster House        990           0
# ..          ...         ...                    ...        ...         ...
# 161       13592  1575936000          Terrace House       3337           0
# 162       13600  1575244800          Terrace House       1561           0
# 163       13603  1575763200          Terrace House       2476           0
# 164       13606  1575849600          Terrace House       1195           0
# 165       13632  1576713600  Condominium/Apartment       1539           1
#
#      bedrooms              street_name  psf    price   planning_region
# 0         3.0             JALAN HELANG  310   610000            Kepong
# 1         3.0      LORONG LANG HITAM 6  468   720000            Kepong
# 2         3.0  JALAN LANG KEPALA PUTIH  435   670000            Kepong
# 3         3.0         JALAN CHIAK RAYA  336  1100000            Kepong
# 4         2.0            JALAN JUJUR 3  283   280000  Bandar Tun Razak
# ..        ...                      ...  ...      ...               ...
# 161       3.0           JALAN USJ 11/7  330  1100000               USJ
# 162       3.0           JALAN USJ 2/4E  432   675000               USJ
# 163       3.0          JALAN USJ 22/2B  343   850000               USJ
# 164       3.0           JALAN USJ 3/4B  619   740000               USJ
# 165       3.0       PERSIARAN PUTERI 1   78   120000   Batu 9th Cheras
#
# [160 rows x 10 columns]

# %% [markdown]
# ## Integration

# %%
pois['category'].value_counts()
# Out:
# education         961
# transportation    193
# healthcare        101
# Name: category, dtype: int64

# %% [markdown]
# ## Add new columns nearby_poi_education, nearby_poi_transportation and nearby_poi_healthcare to township dataset

# %%
# create new column to pois, coordinates as a tuple of latitue & longitude
pois['coordinates'] = list(zip(round(pois['latitude'], 4), round(pois['longitude'], 4)))

# calculate distance between two points
def calc_distance(source, target):
    return(distance(source, target).m)


# find nearby township psf
def nearby_poi(target_coordinate):
    # add new column to record distance of POI to target coordinate
    pois['distance'] = pois['coordinates'].apply(
        lambda x: 
        calc_distance(x, target_coordinate)
    )

    # compute summary of total POI counts within 3km for each category
    nearby_pois_count = (
        pois[(pois['distance'] <= 3000) & (pois['category'] == 'education')].count()['name'],
        pois[(pois['distance'] <= 3000) & (pois['category'] == 'transportation')].count()['name'],
        pois[(pois['distance'] <= 3000) & (pois['category'] == 'healthcare')].count()['name']
    )

    # drop the distance column
    pois.drop(['distance'], axis=1, inplace=True)

    print('.', end='')
    
    return (nearby_pois_count)

# %%
# create new column to townships, coordinates as a tuple of latitue & longitude
townships['coordinates'] = list(zip(townships['latitude'], townships['longitude']))

# add new column to Township to record near by POI count
print('Start', datetime.datetime.now())
townships['nearby_pois'] = townships.apply(
    lambda x: nearby_poi((x['coordinates'])), axis=1
)
print()
print('Completed', datetime.datetime.now())
# Out:
# Start 2020-05-22 23:50:48.379903
# ..............................................................................................................................
# Completed 2020-05-22 23:51:11.229702

# %%
# split the tuple returned by the fuction into three new columns 
# nearby_poi_education, nearby_poi_transportation and nearby_poi_healthcare

townships[[
    'nearby_poi_education', 'nearby_poi_transportation', 'nearby_poi_healthcare'
]] = pd.DataFrame(townships['nearby_pois'].tolist(), index=townships.index)                                                                                                                       

townships.drop(['coordinates', 'nearby_pois'], axis=1, inplace=True)
townships
# Out:
#      project_id  latitude   longitude                          project_name  \
# 0         10113  3.200030  101.642998                           Kepong Baru
# 1         16814  3.087248  101.721283     Bandar Tun Razak (Kampung Konggo)
# 2         16319  3.181050  101.672996                        Sri Putramas I
# 3         17003  3.149142  101.624763            Taman Tun Dr Ismail (TTDI)
# 4         25133  3.192106  101.639056  Bandar Menjalara (Desa Seri Mahkota)
# ..          ...       ...         ...                                   ...
# 127       13600  3.060640  101.585999                                 USJ 2
# 128       13603  3.024680  101.584999                                USJ 22
# 129       13606  3.056050  101.571999                                 USJ 3
# 130       13632  3.080259  101.774374                           Venice Hill
# 131       28198  2.899456  101.661448                           PPA1M Larai
#
#             state                 area             street_name  median_psf  \
# 0    Kuala Lumpur               Kepong            JALAN HELANG         388
# 1    Kuala Lumpur     Bandar Tun Razak           JALAN JUJUR 3         294
# 2    Kuala Lumpur              Dutamas        JALAN PUTRAMAS 1         394
# 3    Kuala Lumpur  Taman Tun Dr Ismail  LENGKOK AMINUDDIN BAKI         814
# 4    Kuala Lumpur     Bandar Menjalara              JALAN 6/62         512
# ..            ...                  ...                     ...         ...
# 127      Selangor                  USJ          JALAN USJ 2/4E         432
# 128      Selangor                  USJ         JALAN USJ 22/2B         343
# 129      Selangor                  USJ          JALAN USJ 3/4B         619
# 130      Selangor      Batu 9th Cheras      PERSIARAN PUTERI 1          78
# 131     Putrajaya            Putrajaya               PRESINT 6         216
#
#      median_price  nearby_poi_education  nearby_poi_transportation  \
# 0          775000                    37                         10
# 1          396667                    42                         11
# 2          432667                    58                         16
# 3         1541667                    35                          7
# 4          635000                    35                          9
# ..            ...                   ...                        ...
# 127        675000                    42                         12
# 128        850000                    26                          5
# 129        740000                    33                          7
# 130        120000                    14                          2
# 131        260000                     6                          0
#
#      nearby_poi_healthcare
# 0                        3
# 1                        5
# 2                       10
# 3                        3
# 4                        3
# ..                     ...
# 127                      3
# 128                      2
# 129                      1
# 130                      0
# 131                      0
#
# [126 rows x 12 columns]

# %%
townships.to_csv(township_csv)

# %% [markdown]
# ## Merge Township dataset into Transaction dataset

# %%
# Merge using inner join, transactions without township information will be ignored

transactions = transactions.merge(townships, left_on='project_id', right_on='project_id', suffixes=('', '_township'))

# %%
transactions
# Out:
#      project_id        date          property_type  area_sqft  non_landed  \
# 0         10113  1576454400          Terrace House       1970           0
# 1         10113  1576195200          Terrace House       1539           0
# 2         10113  1576108800          Terrace House       1539           0
# 3         10113  1575936000          Terrace House       3272           0
# 4         16814  1575936000          Cluster House        990           0
# ..          ...         ...                    ...        ...         ...
# 144       13592  1575936000          Terrace House       3337           0
# 145       13600  1575244800          Terrace House       1561           0
# 146       13603  1575763200          Terrace House       2476           0
# 147       13606  1575849600          Terrace House       1195           0
# 148       13632  1576713600  Condominium/Apartment       1539           1
#
#      bedrooms              street_name  psf    price   planning_region  ...  \
# 0         3.0             JALAN HELANG  310   610000            Kepong  ...
# 1         3.0      LORONG LANG HITAM 6  468   720000            Kepong  ...
# 2         3.0  JALAN LANG KEPALA PUTIH  435   670000            Kepong  ...
# 3         3.0         JALAN CHIAK RAYA  336  1100000            Kepong  ...
# 4         2.0            JALAN JUJUR 3  283   280000  Bandar Tun Razak  ...
# ..        ...                      ...  ...      ...               ...  ...
# 144       3.0           JALAN USJ 11/7  330  1100000               USJ  ...
# 145       3.0           JALAN USJ 2/4E  432   675000               USJ  ...
# 146       3.0          JALAN USJ 22/2B  343   850000               USJ  ...
# 147       3.0           JALAN USJ 3/4B  619   740000               USJ  ...
# 148       3.0       PERSIARAN PUTERI 1   78   120000   Batu 9th Cheras  ...
#
#       longitude                       project_name         state  \
# 0    101.642998                        Kepong Baru  Kuala Lumpur
# 1    101.642998                        Kepong Baru  Kuala Lumpur
# 2    101.642998                        Kepong Baru  Kuala Lumpur
# 3    101.642998                        Kepong Baru  Kuala Lumpur
# 4    101.721283  Bandar Tun Razak (Kampung Konggo)  Kuala Lumpur
# ..          ...                                ...           ...
# 144  101.580002                             USJ 11      Selangor
# 145  101.585999                              USJ 2      Selangor
# 146  101.584999                             USJ 22      Selangor
# 147  101.571999                              USJ 3      Selangor
# 148  101.774374                        Venice Hill      Selangor
#
#                  area street_name_township median_psf  median_price  \
# 0              Kepong         JALAN HELANG        388        775000
# 1              Kepong         JALAN HELANG        388        775000
# 2              Kepong         JALAN HELANG        388        775000
# 3              Kepong         JALAN HELANG        388        775000
# 4    Bandar Tun Razak        JALAN JUJUR 3        294        396667
# ..                ...                  ...        ...           ...
# 144               USJ       JALAN USJ 11/7        330       1100000
# 145               USJ       JALAN USJ 2/4E        432        675000
# 146               USJ      JALAN USJ 22/2B        343        850000
# 147               USJ       JALAN USJ 3/4B        619        740000
# 148   Batu 9th Cheras   PERSIARAN PUTERI 1         78        120000
#
#      nearby_poi_education  nearby_poi_transportation  nearby_poi_healthcare
# 0                      37                         10                      3
# 1                      37                         10                      3
# 2                      37                         10                      3
# 3                      37                         10                      3
# 4                      42                         11                      5
# ..                    ...                        ...                    ...
# 144                    35                          8                      1
# 145                    42                         12                      3
# 146                    26                          5                      2
# 147                    33                          7                      1
# 148                    14                          2                      0
#
# [149 rows x 21 columns]

# %%
# compare planning_region in Transaction and area in township.
# only one row produces different value, drop column planning_region

transactions[transactions['area'] != transactions['planning_region']]
# Out:
#     project_id        date  property_type  area_sqft  non_landed  bedrooms  \
# 35        9113  1575244800  Terrace House       3466           0       4.0
#
#                street_name  psf    price planning_region  ...  longitude  \
# 35  JALAN DESA MELAWATI 1A  551  1910000     Wangsa Maju  ...    101.739
#
#      project_name         state            area    street_name_township  \
# 35  Desa Melawati  Kuala Lumpur  Taman Melawati  JALAN DESA MELAWATI 1A
#
#    median_psf  median_price  nearby_poi_education  nearby_poi_transportation  \
# 35        551       1910000                    39                          4
#
#     nearby_poi_healthcare
# 35                      2
#
# [1 rows x 21 columns]

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 0 to 148
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   project_id                 149 non-null    int64
#  1   date                       149 non-null    int64
#  2   property_type              149 non-null    object
#  3   area_sqft                  149 non-null    int64
#  4   non_landed                 149 non-null    int64
#  5   bedrooms                   149 non-null    float64
#  6   street_name                148 non-null    object
#  7   psf                        149 non-null    int64
#  8   price                      149 non-null    int64
#  9   planning_region            149 non-null    object
#  10  latitude                   149 non-null    float64
#  11  longitude                  149 non-null    float64
#  12  project_name               149 non-null    object
#  13  state                      149 non-null    object
#  14  area                       149 non-null    object
#  15  street_name_township       148 non-null    object
#  16  median_psf                 149 non-null    int64
#  17  median_price               149 non-null    int64
#  18  nearby_poi_education       149 non-null    int64
#  19  nearby_poi_transportation  149 non-null    int64
#  20  nearby_poi_healthcare      149 non-null    int64
# dtypes: float64(3), int64(11), object(7)
# memory usage: 25.6+ KB

# %%
# some columns are no longer useful, drop
transactions.drop([
    'date', 'project_id', 'latitude', 'longitude', 'street_name', 'project_name', 
    'psf', 'street_name_township', 'planning_region'
], axis=1, inplace=True)

# %%
transactions
# Out:
#              property_type  area_sqft  non_landed  bedrooms    price  \
# 0            Terrace House       1970           0       3.0   610000
# 1            Terrace House       1539           0       3.0   720000
# 2            Terrace House       1539           0       3.0   670000
# 3            Terrace House       3272           0       3.0  1100000
# 4            Cluster House        990           0       2.0   280000
# ..                     ...        ...         ...       ...      ...
# 144          Terrace House       3337           0       3.0  1100000
# 145          Terrace House       1561           0       3.0   675000
# 146          Terrace House       2476           0       3.0   850000
# 147          Terrace House       1195           0       3.0   740000
# 148  Condominium/Apartment       1539           1       3.0   120000
#
#             state              area  median_psf  median_price  \
# 0    Kuala Lumpur            Kepong         388        775000
# 1    Kuala Lumpur            Kepong         388        775000
# 2    Kuala Lumpur            Kepong         388        775000
# 3    Kuala Lumpur            Kepong         388        775000
# 4    Kuala Lumpur  Bandar Tun Razak         294        396667
# ..            ...               ...         ...           ...
# 144      Selangor               USJ         330       1100000
# 145      Selangor               USJ         432        675000
# 146      Selangor               USJ         343        850000
# 147      Selangor               USJ         619        740000
# 148      Selangor   Batu 9th Cheras          78        120000
#
#      nearby_poi_education  nearby_poi_transportation  nearby_poi_healthcare
# 0                      37                         10                      3
# 1                      37                         10                      3
# 2                      37                         10                      3
# 3                      37                         10                      3
# 4                      42                         11                      5
# ..                    ...                        ...                    ...
# 144                    35                          8                      1
# 145                    42                         12                      3
# 146                    26                          5                      2
# 147                    33                          7                      1
# 148                    14                          2                      0
#
# [149 rows x 12 columns]

# %%
transactions.to_csv(transaction_csv)
